# %%
print('hello');
# Out:
# hello

# %%
# from sympy import*

# x,y,z = symbols('x y z')
# w1 = integrate(x**2+y**2 ,(y,0,x),(x,0,1))
# print( w1)

# double integration
# Out:
# 1/3

# %%
# from sympy import*

# x,y,z = symbols('x y z')
# w1 = integrate(x**2 + y**2 ,(y ,0,x) ,(x ,0 ,1))
# print(w1 )
# Out:
# 1/3

# %%
# from sympy import*

# x,y,z = symbols('x y z')
# w2 = integrate(x*y*z ,(z, 0 , 3 - x - y) , (y , 0 , 3 - x) , (x , 0 , 3))
# print(w2)

# triple integrations
# Out:
# 81/80

# %%
# from sympy import*

# x = Symbol('x')
# y = Symbol('y')
# z = Symbol('z')

# w2 = integrate((x*y*z),(z,0,3-x-y),(y,0,3-x),(x,0,3))
# print(w2)
# Out:
# 81/80

# %%
# from sympy import*

# x = Symbol('x')
# y = Symbol('y')

# w1 = integrate(x**2 + y**2, y , x)
# # print(w1)
# pprint(w1)
# print()
# w2 = integrate(x**2 + y**2 , x , y)
# # print(w2)
# pprint(w2)

# if(w1 == w2):
#     print("they are equal")
# else:
#     print("No they are not ")

# %%
# from sympy import*

# x,y = symbols('x y')
# # are this just comments
# a=4
# b=6
# w1 = 4 * integrate(1, (y , 0 , (b/a)*sqrt(a**2 - x**2)) , (x , 0 ,a))

# pprint(w1)
# Out:
# 24.0⋅π

# %%
# from sympy import*

# r,t = symbols('r t')

# a = 4
# w1 = integrate(r , (r , 0 , a*(1 + cos(t))) , (t , 0, pi))

# pprint(w1)
# Out:
# 12⋅π

# %%
# import numpy as np
# import matplotlib.pyplot as plt
# from sympy import symbols, cos, sin, plot_parametric

# # Method 1: Using Matplotlib (visual plot)
# def plot_cardioid_matplotlib():
#     theta = np.linspace(0, 2*np.pi, 1000)
#     # Cardioid equation: r = 2(1 + cos(θ))
#     r = 2 * (1 + np.cos(theta))
#     x = r * np.cos(theta)
#     y = r * np.sin(theta)
    
#     plt.figure(figsize=(8, 8))
#     plt.plot(x, y)
#     plt.title('Cardioid: r = 2(1 + cos(θ))')
#     plt.axis('equal')
#     plt.grid(True)
#     plt.show()

# # Method 2: Using SymPy (symbolic representation)
# def show_cardioid_sympy():
#     t = symbols('t')
#     # Parametric equations
#     x = 2*cos(t) * (1 + cos(t))
#     y = 2*sin(t) * (1 + cos(t))
#     plot_parametric(x, y, (t, 0, 2*np.pi))

# # Execute both methods
# plot_cardioid_matplotlib()
# show_cardioid_sympy()

# %%
# from sympy import*

# x , y ,z = symbols('x y z')
# a = 2
# b = 3
# c = 4
# w1 = integrate()

# %%
# import numpy as np
# import matplotlib.pyplot as plt
# from mpl_toolkits.mplot3d import Axes3D
# from mpl_toolkits.mplot3d.art3d import Poly3DCollection

# # Define vertices
# vertices = np.array([[0, 0, 0],  # base
#                     [1, 0, 0],  # base
#                     [0.5, np.sqrt(0.75), 0],  # base
#                     [0.5, 0.28867513459481287, 0.8164965809277259]])  # apex

# # Define faces using vertex indices
# faces = [[vertices[0], vertices[1], vertices[2]],  # base
#          [vertices[0], vertices[1], vertices[3]],  # side
#          [vertices[1], vertices[2], vertices[3]],  # side
#          [vertices[0], vertices[2], vertices[3]]]  # side

# # Create 3D plot
# fig = plt.figure()
# ax = fig.add_subplot(111, projection='3d')

# # Add faces
# collection = Poly3DCollection(faces, alpha=0.25)
# collection.set_facecolor('cyan')
# ax.add_collection3d(collection)

# # Add edges
# for i, j in [(0,1), (1,2), (2,0), (0,3), (1,3), (2,3)]:
#     ax.plot([vertices[i][0], vertices[j][0]],
#             [vertices[i][1], vertices[j][1]],
#             [vertices[i][2], vertices[j][2]], 'k-')

# # Set plot parameters
# ax.set_xlabel('X')
# ax.set_ylabel('Y')
# ax.set_zlabel('Z')
# ax.set_title('Tetrahedron')

# # Set equal aspect ratio
# ax.set_box_aspect([1,1,1])

# plt.show()

# %%
# from sympy import*

# x,y,z = symbols('x y z')
# a,b,c = symbols('a b c')

# a = 2
# b = 3
# c = 4

# w1 = integrate(1 , (z , 0 , c* ( 1 - (x/a + y/b))) , ( y , 0 , b*(1 - x/a)) , ( x , 0 , a)) 
# pprint(w1)

# %%
# from sympy import*

# x = symbols('x')
# # w1 = integrate(exp(-x) , (x , 0 , oo))
# w1 = integrate(exp(-x) , (x , 0 , float('inf')))

# print(w1)
# Out:
# 1

# %%
# from sympy import*

# x = Symbol('x')
# n = 5
# w1 = integrate((exp(-x) * (x ** ( n- 1))) , (x , 0 , float('inf')))

# pprint(w1)

# %%
from sympy import*

x = Symbol('x')
w1 = integrate( exp(-x), (x , 0 , float('inf')))

pprint(w1)
# Out:
# 1
